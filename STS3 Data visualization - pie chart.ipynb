# %% [markdown]
# # STS3 Data Visualization - pie chart
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Step 1: Import the libraries
#
#
# Just like last time, we need to `import` libraries. Today we will use `pandas` and `matplotlib`. Because of their long names we just call them `pd` and `plt` to make it easier.

# %%
import pandas as pd
import matplotlib.pyplot as plt

survey = pd.read_csv('survey.csv')

# %%
survey
# Out:
#      Index  Q1  Q1_text  Q2 Q2_text  Q3       Q3_text  Q4 Q4_text  Q5  ...  \
# 0     6101   1  Grade 6   1    Male   2  With parents   2      No   2  ...
# 1     6102   1  Grade 6   1    Male   2  With parents   2      No   3  ...
# 2     6103   1  Grade 6   2  Female   2  With parents   1     Yes   1  ...
# 3     6104   1  Grade 6   2  Female   1          Dorm   1     Yes   3  ...
# 4     6105   1  Grade 6   1    Male   2  With parents   2      No   3  ...
# ..     ...  ..      ...  ..     ...  ..           ...  ..     ...  ..  ...
# 182   8017   3  Grade 8   1    Male   2  With parents   2      No   4  ...
# 183   8018   3  Grade 8   2  Female   1          Dorm   2      No   4  ...
# 184   8019   3  Grade 8   1    Male   2  With parents   2      No   5  ...
# 185   8020   3  Grade 8   1    Male   2  With parents   2      No   4  ...
# 186   8021   3  Grade 8   1    Male   2  With parents   2      No   4  ...
#
#      Q24      Q24_text  Q25      Q25_text  Q26              Q26_text  Q27  \
# 0    2.0   Once a year  5.0  Very healthy  3.0               Neutral  4.0
# 1    5.0     Every day  5.0  Very healthy  4.0       Quite motivated  3.0
# 2    1.0         Never  3.0       Neutral  1.0  Not motivated at all  5.0
# 3    3.0  Once a month  4.0       Healthy  2.0              A little  2.0
# 4    4.0   Once a week  3.0       Neutral  3.0               Neutral  5.0
# ..   ...           ...  ...           ...  ...                   ...  ...
# 182  3.0  Once a month  5.0  Very healthy  4.0       Quite motivated  4.0
# 183  1.0         Never  3.0       Neutral  1.0  Not motivated at all  2.0
# 184  2.0   Once a year  5.0  Very healthy  5.0        Very motivated  5.0
# 185  4.0   Once a week  4.0       Healthy  5.0        Very motivated  5.0
# 186  4.0   Once a week  5.0  Very healthy  5.0        Very motivated  5.0
#
#         Q27_text  Q28            Q28_text
# 0         Useful  4.0  A few times a week
# 1        Neutral  3.0         Once a week
# 2    Very useful  4.0  A few times a week
# 3       A little  4.0  A few times a week
# 4    Very useful  3.0         Once a week
# ..           ...  ...                 ...
# 182       Useful  4.0  A few times a week
# 183     A little  2.0        Once a month
# 184  Very useful  5.0           Every day
# 185  Very useful  5.0           Every day
# 186  Very useful  5.0           Every day
#
# [187 rows x 56 columns]

# %% [markdown]
# We now know how to calculate procentages and store that in a variable.
#
# `Q15_percentages = survey['Q15_text'].value_counts(normalize=True) * 100`
#
# We can do if for any question in the survey!
#
# `my_question_percentages = survey['my_question'].value_counts(normalize=True) * 100`
#
# One way to show the results is by using **bar chart** like we did last time.
#
#
# ![image.png](attachment:image.png)
#
# Today, we will make **pie charts**
#
# Let's check how many students like to read books in English!

# %% [markdown]
# To do this, we need to first calculate the percentages.

# %%
# Create a variable to calculate percentages 
Q15_percentages = survey['Q15_text'].value_counts(normalize=True) * 100

# %% [markdown]
# After that, the easiest way to display a pie chart is:

# %%
plt.pie(Q15_percentages)
plt.show()

# %% [markdown]
# But what if we want to know what each "slice" is about?

# %%
#we add labels
plt.pie(Q15_percentages, labels=Q15_percentages.index)
plt.show()

# %% [markdown]
# But what if we want to know the % for each slice?

# %%
# We add percentages!


plt.pie(Q15_percentages, labels=Q15_percentages.index, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# But what if we want to change colors and add a title?

# %%
# Example custom colors (ensure the number of colors is the same as the number of answers)
colors = ['pink','magenta', 'violet', 'plum', 'purple']

plt.pie(Q15_percentages, labels=Q15_percentages.index, colors=colors, autopct='%1.1f%%')
plt.title("Question 15: Do you like to read books in English?")
plt.show()

# %% [markdown]
# # Make your own pie chart!
#
# 1. Choose the question you want to look at.
# 2. Calculate the procentages.
# 3. Make the pie chart.

# %% [markdown]
# ```
# Q15_percentages = survey['Q15_text'].value_counts(normalize=True) * 100
#
# colors = ['pink','magenta', 'violet', 'plum', 'purple']
#
# plt.pie(Q15_percentages, labels=Q15_percentages.index, colors=colors, autopct='%1.1f%%')
# plt.title("Question 15: Do you like to read books in English?")
# plt.show()
# ```

# %% [markdown]
# here's a list of colors you can choose from:

# %%
import pprint
import matplotlib.colors as mcolors

colors = sorted(mcolors.CSS4_COLORS.keys())
pprint.pprint(colors, width=100)
# Out:
# ['aliceblue',
#  'antiquewhite',
#  'aqua',
#  'aquamarine',
#  'azure',
#  'beige',
#  'bisque',
#  'black',
#  'blanchedalmond',
#  'blue',
#  'blueviolet',
#  'brown',
#  'burlywood',
#  'cadetblue',
#  'chartreuse',
#  'chocolate',
#  'coral',
#  'cornflowerblue',
#  'cornsilk',
#  'crimson',
#  'cyan',
#  'darkblue',
#  'darkcyan',
#  'darkgoldenrod',
#  'darkgray',
#  'darkgreen',
#  'darkgrey',
#  'darkkhaki',
#  'darkmagenta',
#  'darkolivegreen',
#  'darkorange',
#  'darkorchid',
#  'darkred',
#  'darksalmon',
#  'darkseagreen',
#  'darkslateblue',
#  'darkslategray',
#  'darkslategrey',
#  'darkturquoise',
#  'darkviolet',
#  'deeppink',
#  'deepskyblue',
#  'dimgray',
#  'dimgrey',
#  'dodgerblue',
#  'firebrick',
#  'floralwhite',
#  'forestgreen',
#  'fuchsia',
#  'gainsboro',
#  'ghostwhite',
#  'gold',
#  'goldenrod',
#  'gray',
#  'green',
#  'greenyellow',
#  'grey',
#  'honeydew',
#  'hotpink',
#  'indianred',
#  'indigo',
#  'ivory',
#  'khaki',
#  'lavender',
#  'lavenderblush',
#  'lawngreen',
#  'lemonchiffon',
#  'lightblue',
#  'lightcoral',
#  'lightcyan',
#  'lightgoldenrodyellow',
#  'lightgray',
#  'lightgreen',
#  'lightgrey',
#  'lightpink',
#  'lightsalmon',
#  'lightseagreen',
#  'lightskyblue',
#  'lightslategray',
#  'lightslategrey',
#  'lightsteelblue',
#  'lightyellow',
#  'lime',
#  'limegreen',
#  'linen',
#  'magenta',
#  'maroon',
#  'mediumaquamarine',
#  'mediumblue',
#  'mediumorchid',
#  'mediumpurple',
#  'mediumseagreen',
#  'mediumslateblue',
#  'mediumspringgreen',
#  'mediumturquoise',
#  'mediumvioletred',
#  'midnightblue',
#  'mintcream',
#  'mistyrose',
#  'moccasin',
#  'navajowhite',
#  'navy',
#  'oldlace',
#  'olive',
#  'olivedrab',
#  'orange',
#  'orangered',
#  'orchid',
#  'palegoldenrod',
#  'palegreen',
#  'paleturquoise',
#  'palevioletred',
#  'papayawhip',
#  'peachpuff',
#  'peru',
#  'pink',
#  'plum',
#  'powderblue',
#  'purple',
#  'rebeccapurple',
#  'red',
#  'rosybrown',
#  'royalblue',
#  'saddlebrown',
#  'salmon',
#  'sandybrown',
#  'seagreen',
#  'seashell',
#  'sienna',
#  'silver',
#  'skyblue',
#  'slateblue',
#  'slategray',
#  'slategrey',
#  'snow',
#  'springgreen',
#  'steelblue',
#  'tan',
#  'teal',
#  'thistle',
#  'tomato',
#  'turquoise',
#  'violet',
#  'wheat',
#  'white',
#  'whitesmoke',
#  'yellow',
#  'yellowgreen']

# %%
#Change the code for your question
Qxx_percentages = survey['Qxx_text'].value_counts(normalize=True) * 100

colors = ['xxx','xxx', 'xxxx', 'xxxx', 'xxxx']

plt.pie(Qxx_percentages, labels=Qxx_percentages.index, colors=colors, autopct='%1.1f%%')
plt.title("Question xx: xxxxxxxxxxxxxxxxx.")
plt.show()
