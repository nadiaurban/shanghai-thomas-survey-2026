# %% [markdown]
# # STS5 Grouping data - bar charts

# %% [markdown]
# ## Step 1. Import the libraries, load the survey and check if it works.
#
# ## You must run this code!!!

# %%
import pandas as pd
import matplotlib.pyplot as plt

survey = pd.read_csv('survey.csv')

# %%
survey
# Out:
#      Index  Q1  Q1_text  Q2 Q2_text  Q3       Q3_text  Q4 Q4_text  Q5  ...  \
# 0     6101   1  Grade 6   1    Male   2  With parents   2      No   2  ...
# 1     6102   1  Grade 6   1    Male   2  With parents   2      No   3  ...
# 2     6103   1  Grade 6   2  Female   2  With parents   1     Yes   1  ...
# 3     6104   1  Grade 6   2  Female   1          Dorm   1     Yes   3  ...
# 4     6105   1  Grade 6   1    Male   2  With parents   2      No   3  ...
# ..     ...  ..      ...  ..     ...  ..           ...  ..     ...  ..  ...
# 182   8017   3  Grade 8   1    Male   2  With parents   2      No   4  ...
# 183   8018   3  Grade 8   2  Female   1          Dorm   2      No   4  ...
# 184   8019   3  Grade 8   1    Male   2  With parents   2      No   5  ...
# 185   8020   3  Grade 8   1    Male   2  With parents   2      No   4  ...
# 186   8021   3  Grade 8   1    Male   2  With parents   2      No   4  ...
#
#      Q24      Q24_text  Q25      Q25_text  Q26              Q26_text  Q27  \
# 0    2.0   Once a year  5.0  Very healthy  3.0               Neutral  4.0
# 1    5.0     Every day  5.0  Very healthy  4.0       Quite motivated  3.0
# 2    1.0         Never  3.0       Neutral  1.0  Not motivated at all  5.0
# 3    3.0  Once a month  4.0       Healthy  2.0              A little  2.0
# 4    4.0   Once a week  3.0       Neutral  3.0               Neutral  5.0
# ..   ...           ...  ...           ...  ...                   ...  ...
# 182  3.0  Once a month  5.0  Very healthy  4.0       Quite motivated  4.0
# 183  1.0         Never  3.0       Neutral  1.0  Not motivated at all  2.0
# 184  2.0   Once a year  5.0  Very healthy  5.0        Very motivated  5.0
# 185  4.0   Once a week  4.0       Healthy  5.0        Very motivated  5.0
# 186  4.0   Once a week  5.0  Very healthy  5.0        Very motivated  5.0
#
#         Q27_text  Q28            Q28_text
# 0         Useful  4.0  A few times a week
# 1        Neutral  3.0         Once a week
# 2    Very useful  4.0  A few times a week
# 3       A little  4.0  A few times a week
# 4    Very useful  3.0         Once a week
# ..           ...  ...                 ...
# 182       Useful  4.0  A few times a week
# 183     A little  2.0        Once a month
# 184  Very useful  5.0           Every day
# 185  Very useful  5.0           Every day
# 186  Very useful  5.0           Every day
#
# [187 rows x 56 columns]

# %% [markdown]
# ## We now know how to group our questions to compare them.
#
# For example we can group by grade (using`'Q1_text'`) or by gender (`Q2_text'`)

# %%
survey["Q11_text"].value_counts(normalize=True) * 100
# Out:
# Q11_text
# Neutral        40.106952
# Quite a lot    19.251337
# Not at all     18.716578
# A little       11.764706
# Very much      10.160428
# Name: proportion, dtype: float64

# %%
#Question 11: How much do you like English?

Q11_by_gender = (survey.groupby('Q2_text')['Q11_text'].value_counts(normalize=True).unstack() * 100).round(0)

Q11_by_gender
# Out:
# Q11_text  A little  Neutral  Not at all  Quite a lot  Very much
# Q2_text
# Female        11.0     44.0        15.0         19.0       11.0
# Male          13.0     36.0        22.0         20.0       10.0

# %%
#Question 7: Do you feel confident speaking English?

Q11_by_grade = (survey.groupby('Q1_text')['Q11_text'].value_counts(normalize=True).unstack() * 100).round(0)

Q11_by_grade
# Out:
# Q11_text  A little  Neutral  Not at all  Quite a lot  Very much
# Q1_text
# Grade 6       14.0     39.0         6.0         28.0       13.0
# Grade 7        4.0     40.0        23.0         19.0       15.0
# Grade 8       14.0     41.0        29.0         11.0        4.0

# %% [markdown]
# ## The best way to compare this is to make a bar chart.
#
# With a bar chart we can easily see the differences!
#
# The easiest way is just this short code:

# %%
Q11_by_gender.T.plot(kind='bar')
plt.show()

# %% [markdown]
# ## Of course we can make our chart much better!
#
# We can **add colors**, **add X label** and a **Y label** as well as a **title**!

# %%
# Plot
colors = ['pink','blue']

Q11_by_gender.T.plot(kind='bar', color=colors)
plt.xlabel('Student Answers')
plt.ylabel('Percentage')
plt.title('Liking English by gender')
plt.legend(title="Gender")
plt.show()

# %% [markdown]
# ## Exercise!
#
# Make a bar chart grouping by gender.
#
# Make a bar chart grouping by grade.
#
#
# You must have **colors**, **X label**, **Y label** and a **title**.
#
# Colors to choose from:

# %%
import pprint
import matplotlib.colors as mcolors

colors = sorted(mcolors.CSS4_COLORS.keys())
pprint.pprint(colors, width=100)
# Out:
# ['aliceblue',
#  'antiquewhite',
#  'aqua',
#  'aquamarine',
#  'azure',
#  'beige',
#  'bisque',
#  'black',
#  'blanchedalmond',
#  'blue',
#  'blueviolet',
#  'brown',
#  'burlywood',
#  'cadetblue',
#  'chartreuse',
#  'chocolate',
#  'coral',
#  'cornflowerblue',
#  'cornsilk',
#  'crimson',
#  'cyan',
#  'darkblue',
#  'darkcyan',
#  'darkgoldenrod',
#  'darkgray',
#  'darkgreen',
#  'darkgrey',
#  'darkkhaki',
#  'darkmagenta',
#  'darkolivegreen',
#  'darkorange',
#  'darkorchid',
#  'darkred',
#  'darksalmon',
#  'darkseagreen',
#  'darkslateblue',
#  'darkslategray',
#  'darkslategrey',
#  'darkturquoise',
#  'darkviolet',
#  'deeppink',
#  'deepskyblue',
#  'dimgray',
#  'dimgrey',
#  'dodgerblue',
#  'firebrick',
#  'floralwhite',
#  'forestgreen',
#  'fuchsia',
#  'gainsboro',
#  'ghostwhite',
#  'gold',
#  'goldenrod',
#  'gray',
#  'green',
#  'greenyellow',
#  'grey',
#  'honeydew',
#  'hotpink',
#  'indianred',
#  'indigo',
#  'ivory',
#  'khaki',
#  'lavender',
#  'lavenderblush',
#  'lawngreen',
#  'lemonchiffon',
#  'lightblue',
#  'lightcoral',
#  'lightcyan',
#  'lightgoldenrodyellow',
#  'lightgray',
#  'lightgreen',
#  'lightgrey',
#  'lightpink',
#  'lightsalmon',
#  'lightseagreen',
#  'lightskyblue',
#  'lightslategray',
#  'lightslategrey',
#  'lightsteelblue',
#  'lightyellow',
#  'lime',
#  'limegreen',
#  'linen',
#  'magenta',
#  'maroon',
#  'mediumaquamarine',
#  'mediumblue',
#  'mediumorchid',
#  'mediumpurple',
#  'mediumseagreen',
#  'mediumslateblue',
#  'mediumspringgreen',
#  'mediumturquoise',
#  'mediumvioletred',
#  'midnightblue',
#  'mintcream',
#  'mistyrose',
#  'moccasin',
#  'navajowhite',
#  'navy',
#  'oldlace',
#  'olive',
#  'olivedrab',
#  'orange',
#  'orangered',
#  'orchid',
#  'palegoldenrod',
#  'palegreen',
#  'paleturquoise',
#  'palevioletred',
#  'papayawhip',
#  'peachpuff',
#  'peru',
#  'pink',
#  'plum',
#  'powderblue',
#  'purple',
#  'rebeccapurple',
#  'red',
#  'rosybrown',
#  'royalblue',
#  'saddlebrown',
#  'salmon',
#  'sandybrown',
#  'seagreen',
#  'seashell',
#  'sienna',
#  'silver',
#  'skyblue',
#  'slateblue',
#  'slategray',
#  'slategrey',
#  'snow',
#  'springgreen',
#  'steelblue',
#  'tan',
#  'teal',
#  'thistle',
#  'tomato',
#  'turquoise',
#  'violet',
#  'wheat',
#  'white',
#  'whitesmoke',
#  'yellow',
#  'yellowgreen']

# %% [markdown]
# **Bar chart grouped by gender**

# %%
XX_grouped_by_gender = (survey.groupby('Q2_text')['XX_text'].value_counts(normalize=True).unstack() * 100).round(0)

XX_grouped_by_gender


# Bar chart
colors = ['XXX','XXX']

XX_grouped_by_gender.T.plot(kind='bar', color=colors)
plt.xlabel('XXX')
plt.ylabel('XXX')
plt.title('XXX')
plt.legend(title="XXX")
plt.show()

# %% [markdown]
# **Bar chart grouped by grade**

# %%
XX_grouped_by_grade = (survey.groupby('Q1_text')['XX_text'].value_counts(normalize=True).unstack() * 100).round(0)

XX_grouped_by_grade


# Bar chart
colors = ['XXX','XXX','XXX']

XX_grouped_by_grade.T.plot(kind='bar', color=colors)
plt.xlabel('XXX')
plt.ylabel('XXX')
plt.title('XXX')
plt.legend(title="XXX")
plt.show()
