# %% [markdown]
# # STS3 Grouping data

# %% [markdown]
# ## Step 1. Import the libraries, load the survey and check if it works.
#
# ## You must run this code!!!

# %%
import pandas as pd
import matplotlib.pyplot as plt

survey = pd.read_csv('survey.csv')

# %%
survey
# Out:
#      Index  Q1  Q1_text  Q2 Q2_text  Q3       Q3_text  Q4 Q4_text  Q5  ...  \
# 0     6101   1  Grade 6   1    Male   2  With parents   2      No   2  ...
# 1     6102   1  Grade 6   1    Male   2  With parents   2      No   3  ...
# 2     6103   1  Grade 6   2  Female   2  With parents   1     Yes   1  ...
# 3     6104   1  Grade 6   2  Female   1          Dorm   1     Yes   3  ...
# 4     6105   1  Grade 6   1    Male   2  With parents   2      No   3  ...
# ..     ...  ..      ...  ..     ...  ..           ...  ..     ...  ..  ...
# 182   8017   3  Grade 8   1    Male   2  With parents   2      No   4  ...
# 183   8018   3  Grade 8   2  Female   1          Dorm   2      No   4  ...
# 184   8019   3  Grade 8   1    Male   2  With parents   2      No   5  ...
# 185   8020   3  Grade 8   1    Male   2  With parents   2      No   4  ...
# 186   8021   3  Grade 8   1    Male   2  With parents   2      No   4  ...
#
#      Q24      Q24_text  Q25      Q25_text  Q26              Q26_text  Q27  \
# 0    2.0   Once a year  5.0  Very healthy  3.0               Neutral  4.0
# 1    5.0     Every day  5.0  Very healthy  4.0       Quite motivated  3.0
# 2    1.0         Never  3.0       Neutral  1.0  Not motivated at all  5.0
# 3    3.0  Once a month  4.0       Healthy  2.0              A little  2.0
# 4    4.0   Once a week  3.0       Neutral  3.0               Neutral  5.0
# ..   ...           ...  ...           ...  ...                   ...  ...
# 182  3.0  Once a month  5.0  Very healthy  4.0       Quite motivated  4.0
# 183  1.0         Never  3.0       Neutral  1.0  Not motivated at all  2.0
# 184  2.0   Once a year  5.0  Very healthy  5.0        Very motivated  5.0
# 185  4.0   Once a week  4.0       Healthy  5.0        Very motivated  5.0
# 186  4.0   Once a week  5.0  Very healthy  5.0        Very motivated  5.0
#
#         Q27_text  Q28            Q28_text
# 0         Useful  4.0  A few times a week
# 1        Neutral  3.0         Once a week
# 2    Very useful  4.0  A few times a week
# 3       A little  4.0  A few times a week
# 4    Very useful  3.0         Once a week
# ..           ...  ...                 ...
# 182       Useful  4.0  A few times a week
# 183     A little  2.0        Once a month
# 184  Very useful  5.0           Every day
# 185  Very useful  5.0           Every day
# 186  Very useful  5.0           Every day
#
# [187 rows x 56 columns]

# %% [markdown]
# ## Okay, now everything else should work :)

# %% [markdown]
# We know how to calculate percentages for any question!
#
# We can change the code to work for any question we want.
#
# `my_question_percentages = (survey['my_question'].value_counts(normalize=True) * 100).round(0)`

# %%
# Create a variable to calculate percentages 

#Q3 "What's your living situation?"
Q3_percentages = (survey['Q3_text'].value_counts(normalize=True) * 100).round(0)


Q3_percentages
# Out:
# Q3_text
# With parents         74.0
# Dorm                 11.0
# Other                11.0
# With grandparents     3.0
# Name: proportion, dtype: float64

# %% [markdown]
# ### Sometimes we want to see answers divided by different groups.
#
# We might want to see if there is a difference between how students answered in **different grades**.
#
# Or  we might want to see if there is a difference between boys and girls.
#
# To see that we need to add `groupby`

# %%
# Calculate percentages for Q3 grouped by Q1_text (grade)
# What's the living situation in different grades? %

Q3_by_grade = (survey.groupby('Q1_text')['Q3_text'].value_counts(normalize=True).unstack() * 100).round(0)

Q3_by_grade
# Out:
# Q3_text  Dorm  Other  With grandparents  With parents
# Q1_text
# Grade 6   6.0   15.0                4.0          75.0
# Grade 7  15.0    9.0                NaN          77.0
# Grade 8  14.0    9.0                4.0          72.0

# %% [markdown]
# In `groupby` we first add the question by which we are grouping.
#
# For example we write `('Q1_text')` first to group by Grade.
#
# Then we write the question we want to check, such as the living situation: `['Q3_text']`.
#
#  First we use `()`, then we use `[]`.

# %% [markdown]
# ## THINK!
#
#
# ### What questions can we group by?

# %% [markdown]
# -----
#
#
# Okay! Let's check which grade is the most confident in speaking English.
#
# To do that we need to take a look at `'Q13_text'` and group it by `'Q1_text.'`

# %%
Q7_by_grade = (survey.groupby('Q1_text')['Q13_text'].value_counts(normalize=True).unstack() * 100).round(0)

Q7_by_grade
# Out:
# Q13_text  A little  Neutral  Not confident at all  Quite confident  \
# Q1_text
# Grade 6       28.0     20.0                  16.0             23.0
# Grade 7       21.0     35.0                  19.0             12.0
# Grade 8       26.0     33.0                  17.0             14.0
#
# Q13_text  Very confident
# Q1_text
# Grade 6             13.0
# Grade 7             12.0
# Grade 8             10.0

# %% [markdown]
# What about girls and boys?
#
# Let's see who feels more confident!
#
# To do that we need to take a look at `'Q7_text'` and group it by `'Q2_text.'`

# %%
Q7_by_gender = (survey.groupby('Q2_text')['Q13_text'].value_counts(normalize=True).unstack() * 100).round(0)

Q7_by_gender
# Out:
# Q13_text  A little  Neutral  Not confident at all  Quite confident  \
# Q2_text
# Female        29.0     32.0                  15.0             13.0
# Male          22.0     26.0                  19.0             21.0
#
# Q13_text  Very confident
# Q2_text
# Female              11.0
# Male                13.0

# %% [markdown]
# ### Exercise: Choose a question a group it by grade. `groupby('Q1_text')`

# %%
Qxx_by_grade = (survey.groupby('Q1_text')['Qxx_text'].value_counts(normalize=True).unstack() * 100).round(0)

Qxx_by_grade

# %% [markdown]
# ### Exercise: Choose a question a group it by gender. `groupby('Q2_text')`

# %%
Qxx_by_gender = (survey.groupby('Q2_text')['Qxx_text'].value_counts(normalize=True).unstack() * 100).round(0)

Qxx_by_gender
